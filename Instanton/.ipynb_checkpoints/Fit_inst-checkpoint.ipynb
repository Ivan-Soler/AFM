# %%
import matplotlib.pyplot as plt
import numpy as np
import tools
import importlib
from scipy.optimize import curve_fit
import sys
import math
importlib.reload(tools)
# Out:
# <module 'tools' from '/home/ivan/AFM/Instanton/tools.py'>

# %%
importlib.reload(tools)
size_frac=0.25
size_inst=0.45
size_local=5
file="./runns6nt45b2.7nr45t3.1/test_data/profile4dt3.1c528to.dat"
file="./Tony/32x4/profile4dt0c5to.dat"
file="./Tony/45x6/profile4dt0c5to.dat"
density,sizes=tools.read_top(file)
density_2d,sizes_big,index_smal=tools.projection_2d(density,sizes)
inst, a_inst, frac, a_frac, t_frac, t_inst, total=tools.find_max_2d(density_2d,sizes_big,size_frac,size_inst,size_local)
tools.plot_dens_2d(file,density_2d,sizes_big,t_frac)

# %%
def inst(position,maxima,rho):
    #maxim=[23,23]
    return(3/(np.pi*rho**4)*(rho**2/((position[:,0]-maxima[0])**2 + (position[:,1]-maxima[1])**2+rho**2))**4)

# %%
def inst_plot(position,maxima,rho):
    #maxim=[23,23]
    return(3/(np.pi*rho**4)*(rho**2/((position[0]-maxima[0])**2 + (position[1]-maxima[1])**2+rho**2))**4)

# %%
x=[]
y=[]
data=[]
neigh=2
maxima=frac[0]
for i in range(-neigh,neigh+1):
    for j in range(-neigh,neigh+1):
        x=int(maxima[0])+i
        y=int(maxima[1])+j
        data.append([x,y,density_2d[x,y]])
data=np.array(data)

# %%
data
# Out:
# array([[2.10000000e+01, 2.10000000e+01, 7.28544186e-03],
#        [2.10000000e+01, 2.20000000e+01, 1.14977060e-02],
#        [2.10000000e+01, 2.30000000e+01, 1.18739957e-02],
#        [2.10000000e+01, 2.40000000e+01, 7.82233133e-03],
#        [2.10000000e+01, 2.50000000e+01, 3.63567336e-03],
#        [2.20000000e+01, 2.10000000e+01, 1.37426838e-02],
#        [2.20000000e+01, 2.20000000e+01, 2.30685044e-02],
#        [2.20000000e+01, 2.30000000e+01, 2.38781086e-02],
#        [2.20000000e+01, 2.40000000e+01, 1.49521900e-02],
#        [2.20000000e+01, 2.50000000e+01, 6.43713643e-03],
#        [2.30000000e+01, 2.10000000e+01, 1.71045796e-02],
#        [2.30000000e+01, 2.20000000e+01, 2.94170093e-02],
#        [2.30000000e+01, 2.30000000e+01, 3.05034609e-02],
#        [2.30000000e+01, 2.40000000e+01, 1.86399114e-02],
#        [2.30000000e+01, 2.50000000e+01, 7.76391767e-03],
#        [2.40000000e+01, 2.10000000e+01, 1.30972880e-02],
#        [2.40000000e+01, 2.20000000e+01, 2.19264694e-02],
#        [2.40000000e+01, 2.30000000e+01, 2.27582083e-02],
#        [2.40000000e+01, 2.40000000e+01, 1.42406792e-02],
#        [2.40000000e+01, 2.50000000e+01, 6.15167250e-03],
#        [2.50000000e+01, 2.10000000e+01, 6.72556385e-03],
#        [2.50000000e+01, 2.20000000e+01, 1.05174350e-02],
#        [2.50000000e+01, 2.30000000e+01, 1.08005575e-02],
#        [2.50000000e+01, 2.40000000e+01, 7.19657616e-03],
#        [2.50000000e+01, 2.50000000e+01, 3.40230545e-03]])

# %%
popt, pcov = curve_fit(lambda position,rho:inst(position,maxima,rho), data[:,:2], data[:,2])

# %%
data_plot=np.zeros((sizes_big[0],sizes_big[1]))
for i in range(0,sizes_big[0]):
    for j in range(0,sizes_big[1]):
        data_plot[i,j]=inst_plot([i,j],maxima,popt[0])

# %%
points=np.zeros((sizes[2],sizes[3]))

X = np.arange(0,sizes[2])
Y = np.arange(0,sizes[3])
X, Y = np.meshgrid(X, Y)

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
ax.plot_surface(X,Y,data_plot)
